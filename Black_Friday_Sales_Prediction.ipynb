# %%
#importing the necessary libraries needed.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('sales.csv.txt')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
len(df['Age'].unique())
# Out:
# 7

# %%
df.describe().transpose()
# Out:
#                        count          mean          std        min        25%  \
# User_ID             550068.0  1.003029e+06  1727.591586  1000001.0  1001516.0
# Occupation          550068.0  8.076707e+00     6.522660        0.0        2.0
# Marital_Status      550068.0  4.096530e-01     0.491770        0.0        0.0
# Product_Category_1  550068.0  5.404270e+00     3.936211        1.0        1.0
# Product_Category_2  376430.0  9.842329e+00     5.086590        2.0        5.0
# Product_Category_3  166821.0  1.266824e+01     4.125338        3.0        9.0
# Purchase            550068.0  9.263969e+03  5023.065394       12.0     5823.0
#
#                           50%        75%        max
# User_ID             1003077.0  1004478.0  1006040.0
# Occupation                7.0       14.0       20.0
# Marital_Status            0.0        1.0        1.0
# Product_Category_1        5.0        8.0       20.0
# Product_Category_2        9.0       15.0       18.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.apply(lambda x: len(x.unique()))
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               18
# Product_Category_3               16
# Purchase                      18105
# dtype: int64

# %% [markdown]
#  # Exploratory data Anlaysis

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.distplot(df['Purchase'],bins=25)
# Out:
# C:\Users\appid\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Purchase', ylabel='Density'>

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Occupation',data=df)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x='City_Category',data=df)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x='Marital_Status',data=df)
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(df['Product_Category_2'])
# Out:
# C:\Users\appid\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_2', ylabel='count'>

# %%
sns.countplot(df['Product_Category_1'])
# Out:
# C:\Users\appid\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',data=df)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# # Occupation And Purchase Analysis

# %%
occupation_plot=df.groupby('Occupation').agg({'Purchase':np.mean})

# %%
occupation_plot
# Out:
#                Purchase
# Occupation
# 0           9124.428588
# 1           8953.193270
# 2           8952.481683
# 3           9178.593088
# 4           9213.980251
# 5           9333.149298
# 6           9256.535691
# 7           9425.728223
# 8           9532.592497
# 9           8637.743761
# 10          8959.355375
# 11          9213.845848
# 12          9796.640239
# 13          9306.351061
# 14          9500.702772
# 15          9778.891163
# 16          9394.464349
# 17          9821.478236
# 18          9169.655844
# 19          8710.627231
# 20          8836.494905

# %%
occupation_plot_pivot=df.pivot_table(index='Occupation',values='Purchase',aggfunc=np.mean)

# %%
occupation_plot_pivot
# Out:
#                Purchase
# Occupation
# 0           9124.428588
# 1           8953.193270
# 2           8952.481683
# 3           9178.593088
# 4           9213.980251
# 5           9333.149298
# 6           9256.535691
# 7           9425.728223
# 8           9532.592497
# 9           8637.743761
# 10          8959.355375
# 11          9213.845848
# 12          9796.640239
# 13          9306.351061
# 14          9500.702772
# 15          9778.891163
# 16          9394.464349
# 17          9821.478236
# 18          9169.655844
# 19          8710.627231
# 20          8836.494905

# %%
#np.sum
occupation_plot_pivot=df.pivot_table(index='Occupation',values='Purchase',aggfunc=np.sum)
plt.style.use('fivethirtyeight')
occupation_plot_pivot.plot(kind='bar',figsize=(12,6))
plt.xlabel("Occupation")
plt.ylabel('Purchase')
plt.title("Occupation and Purchase Analysis");
plt.show()

# %%
#np.mean
occupation_plot_pivot=df.pivot_table(index='Occupation',values='Purchase',aggfunc=np.mean)
plt.style.use('fivethirtyeight')
occupation_plot_pivot.plot(kind='bar',figsize=(12,6))
plt.xlabel("Occupation")
plt.ylabel('Purchase')
plt.title("Occupation and Purchase Analysis");
plt.show()

# %% [markdown]
# # Age And Purchase Analysis

# %%
Age_plot_pivot=df.pivot_table(index='Age',values='Purchase',aggfunc=np.mean)

# %%
Age_plot_pivot
# Out:
#           Purchase
# Age
# 0-17   8933.464640
# 18-25  9169.663606
# 26-35  9252.690633
# 36-45  9331.350695
# 46-50  9208.625697
# 51-55  9534.808031
# 55+    9336.280459

# %%
#np.mean
Age_plot_pivot=df.pivot_table(index='Age',values='Purchase',aggfunc=np.mean)
plt.style.use('fivethirtyeight')
Age_plot_pivot.plot(kind='bar',figsize=(12,6))
plt.xlabel("Age")
plt.ylabel('Purchase')
plt.title("Age and Purchase Analysis");
plt.show()

# %%
#np.mean
Age_plot_pivot=df.pivot_table(index='Age',values='Purchase',aggfunc=np.sum)
plt.style.use('fivethirtyeight')
Age_plot_pivot.plot(kind='bar',figsize=(12,6))
plt.xlabel("Age")
plt.ylabel('Purchase')
plt.xticks(rotation=1)
plt.title("Age and Purchase Analysis");
plt.show()

# %% [markdown]
# # Gender And Purchase Analysis

# %%
Gender_plot_pivot=df.pivot_table(index='Gender',values='Purchase',aggfunc=np.mean)

# %%
Gender_plot_pivot
# Out:
#            Purchase
# Gender
# F       8734.565765
# M       9437.526040

# %%
#np.sum
Gender_plot_pivot=df.pivot_table(index='Gender',values='Purchase',aggfunc=np.sum)
plt.style.use('fivethirtyeight')
Gender_plot_pivot.plot(kind='bar',figsize=(12,6))
plt.xlabel("Gender")
plt.ylabel('Purchase')
plt.xticks(rotation=1)
plt.title("Gender and Purchase Analysis");
plt.show()

# %%
#np.mean
Gender_plot_pivot=df.pivot_table(index='Gender',values='Purchase',aggfunc=np.mean)
plt.style.use('fivethirtyeight')
Gender_plot_pivot.plot(kind='bar',figsize=(12,6))
plt.xlabel("Gender")
plt.ylabel('Purchase')
plt.xticks(rotation=1)
plt.title("Gender and Purchase Analysis");
plt.show()

# %% [markdown]
# # Preprocessing the dataset

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df['Product_Category_2'].mean()
# Out:
# 9.842329251122386

# %%
df['Product_Category_2'].max()
# Out:
# 18.0

# %%
df['Product_Category_2'].min()
# Out:
# 2.0

# %%
df["Product_Category_2"].mode()
# Out:
# 0    8.0
# dtype: float64

# %%
df['Product_Category_2'].median()
# Out:
# 9.0

# %%
df['Product_Category_2']=df['Product_Category_2'].fillna(-2.0).astype('float32')
df['Product_Category_3']=df['Product_Category_3'].fillna(-2.0).astype('float32')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
# encoding values of Gender using a Dictionary

# %%
df['Gender']=df['Gender'].map({'F':0,'M':1})

# %%
df.head()
# Out:
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042       0  0-17          10             A
# 1  1000001  P00248942       0  0-17          10             A
# 2  1000001  P00087842       0  0-17          10             A
# 3  1000001  P00085442       0  0-17          10             A
# 4  1000002  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                -2.0                -2.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
# now label encoding
cols=['Gender','Age','City_Category','Stay_In_Current_City_Years']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for col in cols:
    df[col]=le.fit_transform(df[col])

# %%
df.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation  City_Category  \
# 0  1000001  P00069042       0    0          10              0
# 1  1000001  P00248942       0    0          10              0
# 2  1000001  P00087842       0    0          10              0
# 3  1000001  P00085442       0    0          10              0
# 4  1000002  P00285442       1    6          16              2
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                -2.0                -2.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
for col in cols:
    print(df[col].unique())
# Out:
# [0 1]
# [0 6 2 4 5 3 1]
# [0 2 1]
# [2 4 3 1 0]

# %% [markdown]
# # Correlation Matrix

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
#  # Train_Test_Split

# %%
from sklearn.model_selection import train_test_split,cross_val_score

# %%
df.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation  City_Category  \
# 0  1000001  P00069042       0    0          10              0
# 1  1000001  P00248942       0    0          10              0
# 2  1000001  P00087842       0    0          10              0
# 3  1000001  P00085442       0    0          10              0
# 4  1000002  P00285442       1    6          16              2
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                -2.0                -2.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
X=df.drop(['User_ID','Product_ID','Purchase'],axis=1)
y=df['Purchase']

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
def run_model(model,X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    Mae=mean_absolute_error(y_test,y_pred)
    MSE=mean_squared_error(y_test,y_pred)
    RMSE=np.sqrt(mean_squared_error(y_test,y_pred))
    
    cv_score=cross_val_score(model,X,y,scoring='neg_mean_squared_error',cv=5)
    cv_score=np.abs(np.mean(cv_score))
    print(Mae)
    print(RMSE)
    print('cv_score:',np.sqrt(cv_score))

# %% [markdown]
# # Predictive Modelling

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression(normalize=True)

# %%
run_model(model,X,y)
coef=pd.Series(model.coef_,X.columns).sort_values()
coef.plot(kind='bar')
# Out:
# 3523.3557657213196
# 4617.994034201719
# cv_score: 4625.252945835688
# <AxesSubplot:>

# %%
coef
# Out:
# Product_Category_1           -342.897918
# Marital_Status                -48.007168
# Occupation                      5.609460
# Stay_In_Current_City_Years      7.261369
# Product_Category_2             15.350872
# Age                           104.986736
# Product_Category_3            128.613346
# City_Category                 319.086227
# Gender                        474.635143
# dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model=DecisionTreeRegressor()

# %%
run_model(model,X,y)
coef=pd.Series(model.feature_importances_,X.columns).sort_values()
coef.plot(kind='bar')
# Out:
# 2375.995672122623
# 3367.4155670909786
# cv_score: 3339.1381998107245
# <AxesSubplot:>

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
run_model(model,X,y)
coef=pd.Series(model.feature_importances_,X.columns).sort_values()
coef.plot(kind='bar')
# Out:
# 2375.7323349516178
# 3367.146988527886
# cv_score: 3339.9692545648395
# <AxesSubplot:>

# %%
df['Purchase'].mean()
# Out:
# 9263.968712959126

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
model=ExtraTreesRegressor(n_jobs=-1)

# %%
run_model(model,X,y)
coef=pd.Series(model.feature_importances_,X.columns).sort_values()
coef.plot(kind='bar')
# Out:
# 2286.9353952287483
# 3195.7501981912606
# cv_score: 3180.781473358288
# <AxesSubplot:>

# %%
pred = model.predict(X_test)

# %%
pred
# Out:
# array([13320.61166667, 15930.565     ,  7728.10666667, ...,
#         6175.03846154,  3998.        , 14542.        ])
